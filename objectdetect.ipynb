# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatchintha/Project0/blob/master/objectdetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/nexet.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: nexet/nexet_2017_1/frame_da6046a0f5c71df02e54773aa34226f1_77a6b0ac6aabd5543efb25fc8814f6f8_30000-1280_720.jpg
#   inflating: nexet/nexet_2017_1/frame_da6046a0f5c71df02e54773aa34226f1_7e34ccb4e64d8c6b7d3f2ebba00bdd89_60000-1280_720.jpg
#   inflating: nexet/nexet_2017_1/frame_da6046a0f5c71df02e54773aa34226f1_824a3faa16d53aaee04a78f34a9011e5_60000-1280_720.jpg
#   inflating: nexet/nexet_2017_1/frame_da6046a0f5c71df02e54773aa34226f1_8702d95a2d4c9cba4e267f584b1a9324_0-1280_720.jpg
#   inflating: nexet/nexet_2017_1/frame_da6046a0f5c71df02e54773aa34226f1_8e1fe7735596dfc59b6ab099a4fcdaa1_60000-1280_720.jpg
#   inflating: nexet/nexet_2017_1/frame_da6046a0f5c71df02e54773aa34226f1_8f2dd3a3d74d8987375b0cf92aa64d1f_0-1280_720.jpg
#   inflating: nexet/nexet_2017_1/frame_da6046a0f5c71df02e54773aa34226f1_8f2dd3a3d74d8987375b0cf92aa64d1f_90000-1280_720.jpg
# ...

# %%
# !git clone 'https://github.com/Tessellate-Imaging/Monk_Object_Detection.git'
# Out:
# Cloning into 'Monk_Object_Detection'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 5052 (delta 27), reused 50 (delta 15), pack-reused 4978
# Receiving objects: 100% (5052/5052), 154.06 MiB | 31.57 MiB/s, done.
# Resolving deltas: 100% (1457/1457), done.
# Checking out files: 100% (4714/4714), done.

# %%
import pandas as pd
data = pd.read_csv('nexet/train.csv' )
data.describe()
# Out:
#                                            image_filename lighting   city
# count                                               50000    50000  50000
# unique                                              50000        3      4
# top     incident-0-01cf218d-64ee-478f-888b-579b2402572...      Day    RoW
# freq                                                    1    24903  20000
