# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatchintha/Project0/blob/master/Move_imagesv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd  /content/drive/My Drive/Kaggle/nexet/nexet/nexet_2017_1
# Out:
# /content/drive/My Drive/Kaggle/nexet/nexet/nexet_2017_1

# %%
import subprocess
import sys
import os, shutil
import csv
import pandas as pd
from csv import reader

# %%
image_name = [x for x in os.listdir('/content/drive/My Drive/Kaggle/nexet/nexet/nexet_2017_1') if x.endswith(".jpg")]

print(image_name[0:25])
# Out:
# ['frame_fdd9851a343949a85021140d5311e2ee_4a213b93e446a703edf6c180a88b21a0_0-1280_720.jpg', 'frame_fdc69a88c304348b9ec70505ef385d5f_6d355c3801ee37b24641026f7f94e3a6_90000-1280_720.jpg', 'frame_fdc69a88c304348b9ec70505ef385d5f_ae8583a4858d042427d74234781ebf31_90000-1280_720.jpg', 'frame_fdc4ed1beac0c7dd6c9bac92417efe02_0294fc0fe3430b830ad4f4e82cc44953_30000-1280_720.jpg', 'frame_fdc4ed1beac0c7dd6c9bac92417efe02_c268409fadc7a03d9a558bc1b9010fc6_60000-1280_720.jpg', 'frame_fe0a378d84fd337ebc032b36df284398_323b712bc1d9fcb18ae2b9506bf70d35_30000-1280_720.jpg', 'frame_fdd9851a343949a85021140d5311e2ee_ddaef98159080eee58b58c8ba9f2dd3e_60000-1280_720.jpg', 'frame_fdd9851a343949a85021140d5311e2ee_dbae3d294347ad5a73eeb3fe9ac0e205_60000-1280_720.jpg', 'frame_fe0a378d84fd337ebc032b36df284398_156d8a828076474d439720904b50c226_30000-1280_720.jpg', 'frame_fdc69a88c304348b9ec70505ef385d5f_b170cf097cb698d57e47815d3ae39c38_0-1280_720.jpg', 'frame_fdd9851a343949a85021140d5311e2ee_901dc5921ae9af8d6c9b15d55
# ...

# %%
import pandas as pd
columns=['ID']
df = pd.read_csv('/content/drive/My Drive/Kaggle/nexet/nexet/train_labels.csv',usecols=columns)
label_name = df['ID'].values.tolist()
print(len(image_names))
# Out:
# 49282

# %%
new_list = [
    list(set(image_name).difference(label_name))
]

print(new_list)
# Out:
# [['frame_3f15ace1-ab53-4444-9be5-97e888ee2cb6_00000-1280_720.jpg', 'frame_149238b5-7b81-4372-bcb1-da3daffcb1b8_00000-1280_720.jpg', 'frame_82f505f2-ac61-4b5d-92bb-f92429e0c7c5_00000-1280_720.jpg', 'frame_618a9c04-861a-46dc-a507-bd628e9770bc_00000-720_1280.jpg', 'frame_9535c03cc52733560af7749c9165dd1f_6b5d78e9bce7eb02be96b14fc9b8b44b_30000-1280_720.jpg', 'frame_1a8305c5-9bb1-4bb6-88b3-f40d174f81b8_00000-1280_720.jpg', '1aac5a10-a469-4a58-b797-21803b9bcfb5.mov-0001.jpg', 'frame_d52cd4541e980c75002072bb97be3859_df0183469955429d8aa531741ab0e439_90000-1280_720.jpg', 'frame_de8dfdd7d03e5a337bd7d9e0ace3caa1_d363afcf5b6945e126c6bcb3a9966624_90000-1280_720.jpg', 'frame_9535c03cc52733560af7749c9165dd1f_006bf752499ed45e4c230250bae2d1c2_60000-1280_720.jpg', '3f250248-7721-4aaa-b3d3-c24fa0d91fd7.mov-0001.jpg', 'ca048141-657d-4b28-ae79-834b86893d92.mov-0001.jpg', 'frame_6cfa173a-f325-4043-afcc-9dc48671d720_00000-1280_720.jpg', 'frame_936de0a2-c51a-4d9f-95ef-f75f670ad2e2_00000-1280_720.jpg', '2df1c
# ...

# %%
def returnNotMatches(image_name):
    return [[x for x in image_name if x not in label_name]]
print(len(returnNotMatches(image_name)))
print(returnNotMatches(image_name))
# Out:
# 1
# ...

# %%
def returnNotMatches1(label_name):
    return [[x for x in label_name if x not in image_name]]
print(len(returnNotMatches1(label_name)))
print(returnNotMatches1(label_name))
# Out:
# 1
# [['frame_d26101503e6d32705b0a61346ffcb477_26538516b98bd2a78416af8a27055e3c_30000-1280_720.jpg']]

# %%
lines = list()

members= input("Please enter a member's name to be deleted.")

with open('/content/drive/My Drive/Kaggle/nexet/nexet/train_labels.csv', 'r') as readFile:

    reader = csv.reader(readFile)

    for row in reader:

        lines.append(row)

        for field in row:

            if field == members:

             
                lines.remove(row)

with open('/content/drive/My Drive/Kaggle/nexet/nexet/train_labels.csv', 'w') as writeFile:

    writer = csv.writer(writeFile)

    writer.writerows(lines)
# Out:
# Please enter a member's name to be deleted.frame_d26101503e6d32705b0a61346ffcb477_26538516b98bd2a78416af8a27055e3c_30000-1280_720.jpg

# %%
import pandas as pd
columns=['ID']
df = pd.read_csv('/content/drive/My Drive/Kaggle/nexet/nexet/train_labels.csv',usecols=columns)
label_name = df['ID'].values.tolist()
print(len(image_names))
# Out:
# 49282
